# %% [markdown]
# # **Pré-processamento**

# %% [markdown]
# ## Importação das Bibliotecas

# %%
import pandas as pd
from utils.save_dataframe import save_dataframe
from utils.show_unique_values import show_unique_values
from utils.variables import PROCESSED_DATA_PATH

# %% [markdown]
# ## Carregamento dos Dados

# %% [markdown]
# Carregamos os dados selecionados.

# %%
df = pd.read_csv(PROCESSED_DATA_PATH / "df_selected.csv")
df.head()
# Out:
#         idade       sexo estado presença               cargo  \
# 0  1989-11-29  masculino     ce        s  mestrado/doutorado
# 1  1995-02-23  masculino     rs        s  mestrado/doutorado
# 2  1991-12-13  masculino     sp        s  mestrado/doutorado
# 3  1986-09-29  masculino     pa        s  mestrado/doutorado
# 4  1997-12-26   feminino     am        s  mestrado/doutorado
#
#                            especialidade  algoritmos_e_estruturas_de_dados  \
# 0                   teoria da computação                               1.0
# 1  metodologias e técnicas de computação                               3.0
# 2                 engenharia de software                               1.0
# 3                 sistemas de informação                               2.0
# 4                     computação gráfica                               2.0
#
#    analise_combinatoria  analise_de_algoritmos  \
# 0                   1.0                    1.0
# 1                   2.0                    2.0
# 2                   0.0                    2.0
# 3                   0.0                    1.0
# 4                   1.0                    1.0
#
#    arquitetura_e_organizacao_de_computadores  ...  redes_de_computadores  \
# 0                                        1.0  ...                    1.0
# 1                                        1.0  ...                    2.0
# 2                                        1.0  ...                    1.0
# 3                                        0.0  ...                    2.0
# 4                                        0.0  ...                    1.0
#
#    sistemas_distribuidos  sistemas_operacionais  teoria_dos_grafos  \
# 0                    2.0                    2.0                3.0
# 1                    3.0                    2.0                3.0
# 2                    2.0                    2.0                2.0
# 3                    1.0                    0.0                2.0
# 4                    3.0                    2.0                2.0
#
#    tecnicas_de_programacao  algebra_linear   ano  matematica  fund_computacao  \
# 0                      3.0             2.0  2016        14.0             21.0
# 1                      3.0             3.0  2016        16.0             22.0
# 2                      3.0             1.0  2016         4.0             16.0
# 3                      3.0             1.0  2016         4.0             13.0
# 4                      3.0             2.0  2016         6.0             15.0
#
#    tec_computacao
# 0            10.0
# 1            12.0
# 2             8.0
# 3             7.0
# 4            11.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Limpeza dos Dados

# %% [markdown]
# Visualizamos os valores únicos de cada coluna do `DataFrame` para buscar dados errôneos ou ausentes.

# %%
show_unique_values(df)
# Out:
# idade: ['1989-11-29' '1995-02-23' '1991-12-13' ... '2001-10-07' '1995-10-31'
#  '2000-07-03']
# sexo: ['masculino' 'feminino']
# estado: ['ce' 'rs' 'sp' 'pa' 'am' 'ms' 'pb' 'go' 'rn' 'pr' 'mg' 'se' 'pe' 'es'
#  'rj' 'mt' 'al' 'sc' 'ma' 'pi' 'ba' 'df' 'to' 'ap' 'ro' 'ac' 'rr']
# presença: ['s']
# cargo: ['mestrado/doutorado' 'autoavaliação']
# especialidade: ['teoria da computação' 'metodologias e técnicas de computação'
#  'engenharia de software' 'sistemas de informação' 'computação gráfica'
#  'inteligência artificial' 'informática na educação'
#  'arquitetura de computadores' 'visão computacional'
#  'redes de computadores' 'sistemas de computação' 'banco de dados'
#  'interação humano-computador' 'computação aplicada'
#  'modelagem computacional' 'aplicações computacionais'
#  'processamento paralelo e distribuído' 'sistemas inteligentes'
#  'bioinformática' 'Demais áreas' 'computação visual' 'ciência de dados'
#  'sistemas embarcados' 'otimização' 'aprendizado de máquina'
#  'linguagens de programação' 'robótica' 'tecnologia da informação'
#  'sistemas e tecnologias da computação']
# algoritmos_e_estruturas_de_dados: [ 1.  3.  2.  0. nan]
# analise_combinatoria: [ 1.  2.  0.  3. nan]
# analise_de_algoritmos: [ 1.  2.  3.  0. nan]
# arquitetura_e_organizacao_de_computadores: [ 1.  0.  2.  3. nan]
# banco_de_dados: [ 1.  0.  2.  3. nan]
# calculo_diferencial_e_integral: [ 3.  2.  1.  0. nan]
# circuitos_digitais: [ 3.  2.  1.  0. nan]
# compiladores: [ 1.  0.  2. nan]
# computacao_grafica: [ 0.  2.  1. nan]
# engenharia_de_software: [ 3.  1.  0.  2. nan]
# geometria_analitica: [ 0.  2.  1.  3. nan]
# inteligencia_artificial: [ 1.  2.  0. nan]
# linguagens_de_programacao: [ 3.  2.  1.  0. nan]
# linguagens_formais_automatos_e_computabilidade: [ 2.  1.  3.  0. nan]
# logica_matematica: [ 3.  2.  1.  0. nan]
# matematica_discreta: [ 3.  0.  1.  2. nan]
# organizacao_de_arquivos_e_dados: [ 2.  1.  0.  3. nan]
# probabilidade_e_estatistica: [ 2.  0.  1. nan]
# processamento_de_imagens: [ 1.  2.  0. nan]
# redes_de_computadores: [ 1.  2.  0.  3. nan]
# sistemas_distribuidos: [ 2.  3.  1.  0. nan]
# sistemas_operacionais: [ 2.  0.  3.  1. nan]
# teoria_dos_grafos: [ 3.  2.  1.  0. nan]
# tecnicas_de_programacao: [ 3.  2.  1.  0. nan]
# algebra_linear: [ 2.  3.  1.  0. nan]
# ano: [2016 2017 2018 2019 2022]
# matematica: [14. 16.  4.  6. 12.  9.  7.  5. 19. 11. 17.  8. 10. 13.  2.  3. 15.  1.
#  18. 20.  0.]
# fund_computacao: [21. 22. 16. 13. 15. 20. 17. 14. 10. 12. 23. 11.  8. 24. 19. 18.  9.  7.
#   6. 25. 26.  5.  4. 27. 28.  3.  0.  2.]
# tec_computacao: [10. 12.  8.  7. 11.  4.  3.  6. 15.  9. 13.  5.  2.  1. 14.  0. 16. 17.
#  18.]

# %% [markdown]
# Percebemos que não há valores errôneos mas há alguns valores ausentes nas colunas dos assuntos, então verificamos qual é a natureza do(s) registro(s) em que esses valores aparecem.

# %%
df[df[:].isna().any(axis=1)]
# Out:
#             idade      sexo estado presença               cargo  \
# 11245  1999-08-30  feminino     ce        s  mestrado/doutorado
#
#                especialidade  algoritmos_e_estruturas_de_dados  \
# 11245  redes de computadores                               NaN
#
#        analise_combinatoria  analise_de_algoritmos  \
# 11245                   NaN                    NaN
#
#        arquitetura_e_organizacao_de_computadores  ...  redes_de_computadores  \
# 11245                                        NaN  ...                    NaN
#
#        sistemas_distribuidos  sistemas_operacionais  teoria_dos_grafos  \
# 11245                    NaN                    NaN                NaN
#
#        tecnicas_de_programacao  algebra_linear   ano  matematica  \
# 11245                      NaN             NaN  2022         0.0
#
#        fund_computacao  tec_computacao
# 11245              0.0             0.0
#
# [1 rows x 35 columns]

# %% [markdown]
# Como é apenas um registro, simplesmente removemos ele do `DataFrame`.

# %%
df = df.drop(11245)

# %% [markdown]
# Visualizamos os valores únicos de cada coluna do `DataFrame` novamente para confirmar a remoção dos valores ausentes.

# %%
show_unique_values(df)
# Out:
# idade: ['1989-11-29' '1995-02-23' '1991-12-13' ... '2001-10-07' '1995-10-31'
#  '2000-07-03']
# sexo: ['masculino' 'feminino']
# estado: ['ce' 'rs' 'sp' 'pa' 'am' 'ms' 'pb' 'go' 'rn' 'pr' 'mg' 'se' 'pe' 'es'
#  'rj' 'mt' 'al' 'sc' 'ma' 'pi' 'ba' 'df' 'to' 'ap' 'ro' 'ac' 'rr']
# presença: ['s']
# cargo: ['mestrado/doutorado' 'autoavaliação']
# especialidade: ['teoria da computação' 'metodologias e técnicas de computação'
#  'engenharia de software' 'sistemas de informação' 'computação gráfica'
#  'inteligência artificial' 'informática na educação'
#  'arquitetura de computadores' 'visão computacional'
#  'redes de computadores' 'sistemas de computação' 'banco de dados'
#  'interação humano-computador' 'computação aplicada'
#  'modelagem computacional' 'aplicações computacionais'
#  'processamento paralelo e distribuído' 'sistemas inteligentes'
#  'bioinformática' 'Demais áreas' 'computação visual' 'ciência de dados'
#  'sistemas embarcados' 'otimização' 'aprendizado de máquina'
#  'linguagens de programação' 'robótica' 'tecnologia da informação'
#  'sistemas e tecnologias da computação']
# algoritmos_e_estruturas_de_dados: [1. 3. 2. 0.]
# analise_combinatoria: [1. 2. 0. 3.]
# analise_de_algoritmos: [1. 2. 3. 0.]
# arquitetura_e_organizacao_de_computadores: [1. 0. 2. 3.]
# banco_de_dados: [1. 0. 2. 3.]
# calculo_diferencial_e_integral: [3. 2. 1. 0.]
# circuitos_digitais: [3. 2. 1. 0.]
# compiladores: [1. 0. 2.]
# computacao_grafica: [0. 2. 1.]
# engenharia_de_software: [3. 1. 0. 2.]
# geometria_analitica: [0. 2. 1. 3.]
# inteligencia_artificial: [1. 2. 0.]
# linguagens_de_programacao: [3. 2. 1. 0.]
# linguagens_formais_automatos_e_computabilidade: [2. 1. 3. 0.]
# logica_matematica: [3. 2. 1. 0.]
# matematica_discreta: [3. 0. 1. 2.]
# organizacao_de_arquivos_e_dados: [2. 1. 0. 3.]
# probabilidade_e_estatistica: [2. 0. 1.]
# processamento_de_imagens: [1. 2. 0.]
# redes_de_computadores: [1. 2. 0. 3.]
# sistemas_distribuidos: [2. 3. 1. 0.]
# sistemas_operacionais: [2. 0. 3. 1.]
# teoria_dos_grafos: [3. 2. 1. 0.]
# tecnicas_de_programacao: [3. 2. 1. 0.]
# algebra_linear: [2. 3. 1. 0.]
# ano: [2016 2017 2018 2019 2022]
# matematica: [14. 16.  4.  6. 12.  9.  7.  5. 19. 11. 17.  8. 10. 13.  2.  3. 15.  1.
#  18. 20.  0.]
# fund_computacao: [21. 22. 16. 13. 15. 20. 17. 14. 10. 12. 23. 11.  8. 24. 19. 18.  9.  7.
#   6. 25. 26.  5.  4. 27. 28.  3.  0.  2.]
# tec_computacao: [10. 12.  8.  7. 11.  4.  3.  6. 15.  9. 13.  5.  2.  1. 14.  0. 16. 17.
#  18.]

# %% [markdown]
# Verificamos se há registros duplicados no `DataFrame`.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Como não há registros duplicados, nenhum tratamento precisa ser realizado.

# %% [markdown]
# ## Agrupamento das Especialidades

# %% [markdown]
# Para realizar o agrupamento das especialidades em linhas de pesquisa verificamos quais especialidades estão presentes nos dados.

# %%
df["especialidade"].unique().tolist()
# Out:
# ['teoria da computação',
#  'metodologias e técnicas de computação',
#  'engenharia de software',
#  'sistemas de informação',
#  'computação gráfica',
#  'inteligência artificial',
#  'informática na educação',
#  'arquitetura de computadores',
#  'visão computacional',
#  'redes de computadores',
#  'sistemas de computação',
#  'banco de dados',
#  'interação humano-computador',
#  'computação aplicada',
#  'modelagem computacional',
#  'aplicações computacionais',
#  'processamento paralelo e distribuído',
#  'sistemas inteligentes',
#  'bioinformática',
#  'Demais áreas',
#  'computação visual',
#  'ciência de dados',
#  'sistemas embarcados',
#  'otimização',
#  'aprendizado de máquina',
#  'linguagens de programação',
#  'robótica',
#  'tecnologia da informação',
#  'sistemas e tecnologias da computação']

# %% [markdown]
# - Para a linha de pesquisa **Inteligência Computacional e Ciência de Dados** foram escolhidas especialidades que tenham relação direta com modelagem de sistemas inteligentes que resolvem problemas complexos e busca de conhecimento em bases de dados.
# - Para a linha de pesquisa **Sistemas de Computação** foram escolhidas especialidades que possuiam relação direta tanto com a criação de hardware quanto com a de software.
# - Para a linha de pesquisa **Engenharia de Software** foram escolhidas especialidades que tenham relação direta com conceitos, métodos e técnicas de desenvolvimento, assim como ferramentas e arquiteturas usadas para a criação de softwares.
# - Para a linha de pesquisa **Educação em Computação e Sociedade** foi escolhida apenas a especialidade **Informática na Educação** por ser a única que tem relação direta com a linha de pesquisa.
# - Para a linha de pesquisa **Outras** foram escolhidas aquelas que não se relacionavam diretamente com nenhuma das demais linhas de pesquisa.

# %% [markdown]
# Criamos a função `specialty_to_research` para fazer esse agrupamento de especialidade para linha de pesquisa.

# %%
def specialty_to_reasearch(specialty: str) -> str | None:
    inteligencia_computacional = [
        "inteligência artificial",
        "aprendizado de máquina",
        "ciência de dados",
        "bioinformática",
        "computação visual",
        "sistemas inteligentes",
        "visão computacional",
        "otimização",
        "modelagem computacional",
    ]

    sistemas_computacao = [
        "arquitetura de computadores",
        "redes de computadores",
        "sistemas de computação",
        "processamento paralelo e distribuído",
        "sistemas embarcados",
        "robótica",
        "sistemas e tecnologias da computação",
    ]

    engenharia_software = [
        "engenharia de software",
        "banco de dados",
        "linguagens de programação",
        "tecnologia da informação",
        "interação humano-computador",
        "metodologias e técnicas de computação",
        "sistemas de informação",
    ]

    educacao_computacao = ["informática na educação"]

    outras = [
        "Demais áreas",
        "computação gráfica",
        "teoria da computação",
        "aplicações computacionais",
        "computação aplicada",
    ]

    if specialty in inteligencia_computacional:
        return "Inteligência Artificial e Ciência de Dados"
    if specialty in sistemas_computacao:
        return "Sistemas de Computação"
    if specialty in engenharia_software:
        return "Engenharia de Software e Interação"
    if specialty in educacao_computacao:
        return "Educação em Computação e Sociedade"
    if specialty in outras:
        return "Outras"

    return None

# %% [markdown]
# Criamos a coluna `area` baseando-se nos valores da coluna de `especialidade` usando a função `specialty_to_research`.

# %%
df["linha_de_pesquisa"] = df["especialidade"].apply(specialty_to_reasearch)
df.head()
# Out:
#         idade       sexo estado presença               cargo  \
# 0  1989-11-29  masculino     ce        s  mestrado/doutorado
# 1  1995-02-23  masculino     rs        s  mestrado/doutorado
# 2  1991-12-13  masculino     sp        s  mestrado/doutorado
# 3  1986-09-29  masculino     pa        s  mestrado/doutorado
# 4  1997-12-26   feminino     am        s  mestrado/doutorado
#
#                            especialidade  algoritmos_e_estruturas_de_dados  \
# 0                   teoria da computação                               1.0
# 1  metodologias e técnicas de computação                               3.0
# 2                 engenharia de software                               1.0
# 3                 sistemas de informação                               2.0
# 4                     computação gráfica                               2.0
#
#    analise_combinatoria  analise_de_algoritmos  \
# 0                   1.0                    1.0
# 1                   2.0                    2.0
# 2                   0.0                    2.0
# 3                   0.0                    1.0
# 4                   1.0                    1.0
#
#    arquitetura_e_organizacao_de_computadores  ...  sistemas_distribuidos  \
# 0                                        1.0  ...                    2.0
# 1                                        1.0  ...                    3.0
# 2                                        1.0  ...                    2.0
# 3                                        0.0  ...                    1.0
# 4                                        0.0  ...                    3.0
#
#    sistemas_operacionais  teoria_dos_grafos  tecnicas_de_programacao  \
# 0                    2.0                3.0                      3.0
# 1                    2.0                3.0                      3.0
# 2                    2.0                2.0                      3.0
# 3                    0.0                2.0                      3.0
# 4                    2.0                2.0                      3.0
#
#    algebra_linear   ano  matematica  fund_computacao  tec_computacao  \
# 0             2.0  2016        14.0             21.0            10.0
# 1             3.0  2016        16.0             22.0            12.0
# 2             1.0  2016         4.0             16.0             8.0
# 3             1.0  2016         4.0             13.0             7.0
# 4             2.0  2016         6.0             15.0            11.0
#
#                     linha_de_pesquisa
# 0                              Outras
# 1  Engenharia de Software e Interação
# 2  Engenharia de Software e Interação
# 3  Engenharia de Software e Interação
# 4                              Outras
#
# [5 rows x 36 columns]

# %% [markdown]
# Visualizamos os valores únicos da coluna `area` para verificar se estão corretos.

# %%
df["linha_de_pesquisa"].unique()
# Out:
# array(['Outras', 'Engenharia de Software e Interação',
#        'Inteligência Artificial e Ciência de Dados',
#        'Educação em Computação e Sociedade', 'Sistemas de Computação'],
#       dtype=object)

# %% [markdown]
# ## Seleção dos Atributos para Classificação

# %% [markdown]
# Selecionamos apenas as colunas `matematica`, `fund_computacao` e `tec_computacao` para realizar a classificação nas linhas de pesquisa pois elas representam o número de acertos de cada pessoa em cada campo da prova, tendo assim uma medida de avaliação objetiva e direta para a classificação.

# %%
df_classification_attributes = df[["matematica", "fund_computacao", "tec_computacao", "linha_de_pesquisa"]]
df_classification_attributes.head()
# Out:
#    matematica  fund_computacao  tec_computacao  \
# 0        14.0             21.0            10.0
# 1        16.0             22.0            12.0
# 2         4.0             16.0             8.0
# 3         4.0             13.0             7.0
# 4         6.0             15.0            11.0
#
#                     linha_de_pesquisa
# 0                              Outras
# 1  Engenharia de Software e Interação
# 2  Engenharia de Software e Interação
# 3  Engenharia de Software e Interação
# 4                              Outras

# %% [markdown]
# ## Verificação de Outliers

# %%
def show_outliers(df: pd.DataFrame, column: str) -> None:
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1

    outliers = df[(df[column] < q1 - 1.5 * iqr) | (df[column] > q3 + 1.5 * iqr)]
    print(f"{column}: {outliers[column].unique()}")

# %%
columns = ["matematica", "fund_computacao", "tec_computacao"]

for column in columns:
    show_outliers(df_classification_attributes, column)
# Out:
# matematica: [19. 17. 18. 20.]
# fund_computacao: [27. 28.  0.]
# tec_computacao: [17. 18.]

# %% [markdown]
# ## Persistência dos Dados

# %% [markdown]
# Usamos a função `save_dataframe` para salvar os dados pré-processados.

# %%
save_dataframe(df_classification_attributes, "df_preprocessed")
